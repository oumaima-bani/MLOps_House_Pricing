# %%
import pandas as pd
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, ClassificationPerformancePreset, RegressionPerformancePreset

ref = pd.read_csv("../data/processed.csv").sample(200, random_state=42)
curr = pd.read_csv("../data/processed.csv").sample(200, random_state=0)  # in real life, use new production data

report = Report(metrics=[DataDriftPreset(), RegressionPerformancePreset()])
report.run(reference_data=ref, current_data=curr, column_mapping=None)
report.save_html("../monitoring/report.html")
print("Saved report to monitoring/report.html")
